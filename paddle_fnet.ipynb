# %%
import os, sys
sys.path.append('/workspace/fnet_paddle/PaddleNLP')
import paddlenlp as ppnlp

# %%
torch_large_model_path = 'pretrained_model/torch/large'
tokenizer = ppnlp.transformers.FNetTokenizer.from_pretrained(torch_large_model_path)

# %%
raw_text = 'hello, my bro'
tokenizer(raw_text)
# Out:
# {'input_ids': [4, 109, 6286, 16680, 275, 1145, 5],
#  'token_type_ids': [0, 0, 0, 0, 0, 0, 0]}

# %%
model = ppnlp.transformers.FNetModel()
# Out:
# W1127 16:15:19.940196   579 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 6.0, Driver API Version: 11.0, Runtime API Version: 11.0
# W1127 16:15:19.946225   579 device_context.cc:465] device: 0, cuDNN Version: 8.0.

# %%
model
# Out:
# FNetModel(
#   (embeddings): FNetEmbeddings(
#     (word_embeddings): Embedding(32000, 768, padding_idx=3, sparse=False)
#     (position_embeddings): Embedding(512, 768, sparse=False)
#     (token_type_embeddings): Embedding(4, 768, sparse=False)
#     (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#     (projection): Linear(in_features=768, out_features=768, dtype=float32)
#     (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#   )
#   (encoder): FNetEncoder(
#     (layers): LayerList(
#       (0): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (1): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (2): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (3): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (4): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (5): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (6): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (7): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (8): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (9): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (10): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#       (11): FNetLayer(
#         (fourier): FNetFourierTransform(
#           (self): FNetBasicFourierTransform()
#           (output): FNetBasicOutput(
#             (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           )
#         )
#         (intermediate): FNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, dtype=float32)
#         )
#         (output): FNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, dtype=float32)
#           (layer_norm): LayerNorm(normalized_shape=[768], epsilon=1e-05)
#           (dropout): Dropout(p=0.1, axis=None, mode=upscale_in_train)
#         )
#       )
#     )
#   )
#   (pooler): FNetPooler(
#     (dense): Linear(in_features=768, out_features=768, dtype=float32)
#     (activation): Tanh()
#   )
# )
